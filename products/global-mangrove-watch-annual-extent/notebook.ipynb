# %% [markdown]
# # Look at results

# %%
import geopandas as gpd

abs_asgs_ste_path = "out/gmw_zonal_stats_ste.parquet"

# Read in ASGS STE
asgs_ste_gdf = gpd.read_parquet(abs_asgs_ste_path)

asgs_ste_gdf
# Out:
#                                                                 asgs_ste  \
# zonal_statistics band
# mean             1     MULTIPOLYGON (((159.0623 -31.50886, 159.06218 ...
#                  1     MULTIPOLYGON (((146.29286 -39.15778, 146.29341...
#                  1     MULTIPOLYGON (((142.5314 -10.68301, 142.53072 ...
#                  1     MULTIPOLYGON (((140.66025 -38.06256, 140.66006...
#                  1     MULTIPOLYGON (((117.86953 -35.19108, 117.86961...
#                  1     MULTIPOLYGON (((144.60439 -41.01001, 144.60443...
#                  1     MULTIPOLYGON (((133.02818 -10.90839, 133.02982...
#                  1     POLYGON ((149.06239 -35.1591, 149.09134 -35.14...
#                  1     MULTIPOLYGON (((167.94747 -29.12757, 167.94748...
#
#                        spatial_ref  index  data_variable STE_CODE21  \
# zonal_statistics band
# mean             1               0      0       0.000121          1
# ...
